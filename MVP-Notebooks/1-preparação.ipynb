# %%
# %sql
-- Remove o catálogo 'mvp' e todos os seus objetos (schemas, tabelas, etc) caso exista.
DROP CATALOG IF EXISTS mvp CASCADE

# %%
# %sql
--- Cria o catálogo 'mvp' para organizar schemas e tabelas

CREATE CATALOG mvp

# %%
# %sql
-- Define o catálogo 'mvp' como o contexto atual para operações SQL
USE CATALOG mvp

# %%
# %sql
-- Remove o schema 'staging' e todos os seus objetos (tabelas, views, etc) caso exista
DROP SCHEMA IF EXISTS staging CASCADE

# %%
# %sql
-- Cria o schema 'staging' para armazenar dados intermediários durante o processamento
CREATE SCHEMA staging

# %%
# %sql
-- Remove o schema 'bronze' e todos os seus objetos (tabelas, views, etc) caso exista
DROP SCHEMA IF EXISTS bronze CASCADE

# %%
# %sql
-- Cria o schema 'bronze' para armazenar dados brutos ou de ingestão inicial
CREATE SCHEMA bronze

# %%
# %sql
-- Remove o schema 'silver' e todos os seus objetos (tabelas, views, etc) caso exista
DROP SCHEMA IF EXISTS silver CASCADE

# %%
# %sql
-- Cria o schema 'silver' para armazenar dados tratados e refinados
CREATE SCHEMA silver

# %%
# %sql
-- Remove o schema 'gold' e todos os seus objetos (tabelas, views, etc) caso exista
DROP SCHEMA IF EXISTS gold CASCADE

# %%
# %sql
-- Cria o schema 'gold' para armazenar dados finais ou prontos para consumo analítico
CREATE SCHEMA gold
